# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_excel("C:\\Users\\adity\\Downloads\\Superstore_USA.xlsx")

# %%
dataset = pd.read_excel("C:\\Users\\adity\\Downloads\\Superstore_USA.xlsx")

# %%
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
dataset["Order year"]=dataset['Order Date'].dt.year

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
dataset.shape
# Out:
# (9426, 24)

# %%
dataset['Product Base Margin'] = dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean())

# %% [markdown]
# # Product Margin based on Product Category

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category",y="Product Base Margin",data=dataset,estimator='sum')
plt.show()

# %% [markdown]
# # Top 5 State of Sales

# %%
dataset['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
# Get the top 5 most frequent 'State or Province' values
top_5_states = dataset['State or Province'].value_counts()[:5]
sns.barplot(x=top_5_states.index, y=top_5_states.values)
plt.xlabel('State or Province')
plt.ylabel('Frequency')
plt.title('Top 5 States or Provinces')
plt.show()

# %% [markdown]
# # Profit based on Category

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category",y="Profit",data=dataset,estimator='sum')
plt.show()

# %% [markdown]
# # Order year

# %%
dataset['Order year'].value_counts()
# Out:
# Order year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Order year",data=dataset)
plt.show()

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Product Category",data=dataset)
plt.show()

# %% [markdown]
# # Based on Office Supplies

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="Customer Segment",data=dataset[dataset["Product Category"]=="Office Supplies"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# # Based on Furniture

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=dataset[dataset["Product Category"]=="Furniture"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# # Based on Technology

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=dataset[dataset["Product Category"]=="Technology"],hue="Product Sub-Category")
plt.show()

# %% [markdown]
# # Customer Segment

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=dataset)
plt.show()

# %% [markdown]
# # Ship Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(6,4))
plt.pie(y,labels=x,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Ship Mode",data=dataset,hue="Product Category")
plt.show()

# %% [markdown]
# # Order Priority

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Order Priority",data=dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()

# %%
#dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
#dataset['Order Priority']=dataset["Order Priority"].replace("Critical","Critical")
